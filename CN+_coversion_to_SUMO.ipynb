# %%
import pandas as pd
import numpy as np

# %%
#loading the complete datset CSV file. Also can be imported only part of the dataset by different dates.
df = pd.read_csv('CN+_Dataset.csv',sep=',')
# Out:
#              Date      Time     Direction  Number    Type Temperature  \
# 0      2022.05.24  17:00:01  Direction 13       2  Normal       61 °F
# 1      2022.05.24  17:00:24  Direction 13       2  Normal       61 °F
# 2      2022.05.24  17:00:25   Direction 6       3  Normal       61 °F
# 3      2022.05.24  17:00:26  Direction 13       2  Normal       61 °F
# 4      2022.05.24  17:00:27   Direction 6       2  Normal       61 °F
# ...           ...       ...           ...     ...     ...         ...
# 15017  2022.08.06  16:54:06   Direction 4       1  Normal       68 °F
# 15018  2022.08.06  16:54:41  Direction 13       2  Normal       68 °F
# 15019  2022.08.06  16:54:48   Direction 6       1  Normal       68 °F
# 15020  2022.08.06  16:54:52   Direction 6       2  Normal       68 °F
# 15021  2022.08.06  16:54:58  Direction 13       1  Normal       68 °F
#
#       Dew Point Humidity Wind Wind Speed Wind Gust  Pressure
# 0         48 °F     63 %  WSW     15 mph     0 mph  29.71 in
# ...

# %%
#Convert data in the CSV file into SUMO format based on diffrent routes and vehicle types (Trams. Buses and Normal)
vehicleid=0
xml=[]
for i in range (0, len(df)):
    if df['Type'][i]=='Normal':
        
        for n in range (0, int(df['Number'][i])):
            
            if int(df['Time'][i][3:5]) <12:
                xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8]))+'.00" route="route_'+str(int(df['Direction'][i].split(" ",1)[1])-1)+'"/>')
                vehicleid=vehicleid+1    
            elif int(df['Time'][i][3:5]) <27:
                xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(5*60))+'.00" route="route_'+str(int(df['Direction'][i].split(" ",1)[1])-1)+'"/>')
                vehicleid=vehicleid+1    
            elif int(df['Time'][i][3:5]) <42:
                xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(10*60))+'.00" route="route_'+str(int(df['Direction'][i].split(" ",1)[1])-1)+'"/>')
                vehicleid=vehicleid+1    
            elif int(df['Time'][i][3:5]) <62:
                xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(15*60))+'.00" route="route_'+str(int(df['Direction'][i].split(" ",1)[1])-1)+'"/>')
                vehicleid=vehicleid+1    
            else:
                print('Something Wrong')
                
    elif df['Type'][i]==' Bus' or df['Type'][i]=='Bus' or df['Type'][i]=='Bus ' or df['Type'][i]==' Bus ':
        
        for n in range (0, int(df['Number'][i])):
            
            if int(df['Time'][i][3:5]) <12:
                
                if int(df['Direction'][i].split(" ",1)[1]) == 1:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8]))+'.00" route="route_'+str(16)+'"/>')
                    vehicleid=vehicleid+1  
                elif int(df['Direction'][i].split(" ",1)[1]) == 3:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8]))+'.00" route="route_'+str(17)+'"/>')
                    vehicleid=vehicleid+1  
                elif int(df['Direction'][i].split(" ",1)[1]) == 5:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8]))+'.00" route="route_'+str(18)+'"/>')
                    vehicleid=vehicleid+1
                elif int(df['Direction'][i].split(" ",1)[1]) == 6:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8]))+'.00" route="route_'+str(14)+'"/>')
                    vehicleid=vehicleid+1
                elif int(df['Direction'][i].split(" ",1)[1]) == 13:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8]))+'.00" route="route_'+str(15)+'"/>')
                    vehicleid=vehicleid+1  
                elif int(df['Direction'][i].split(" ",1)[1]) == 14:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8]))+'.00" route="route_'+str(19)+'"/>')
                    vehicleid=vehicleid+1  
                else:
                    print('Something Wrong')
                    
            elif int(df['Time'][i][3:5]) <27:
                if int(df['Direction'][i].split(" ",1)[1]) == 1:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(5*60))+'.00" route="route_'+str(16)+'"/>')
                    vehicleid=vehicleid+1
                elif int(df['Direction'][i].split(" ",1)[1]) == 3:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(5*60))+'.00" route="route_'+str(17)+'"/>')
                    vehicleid=vehicleid+1  
                elif int(df['Direction'][i].split(" ",1)[1]) == 5:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(5*60))+'.00" route="route_'+str(18)+'"/>')
                    vehicleid=vehicleid+1  
                elif int(df['Direction'][i].split(" ",1)[1]) == 6:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(5*60))+'.00" route="route_'+str(14)+'"/>')
                    vehicleid=vehicleid+1  
                elif int(df['Direction'][i].split(" ",1)[1]) == 13:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(5*60))+'.00" route="route_'+str(15)+'"/>')
                    vehicleid=vehicleid+1  
                elif int(df['Direction'][i].split(" ",1)[1]) == 14:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(5*60))+'.00" route="route_'+str(19)+'"/>')
                    vehicleid=vehicleid+1  
                else:
                    print('Something Wrong')
                    
            elif int(df['Time'][i][3:5]) <42:
                if int(df['Direction'][i].split(" ",1)[1]) == 1:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(10*60))+'.00" route="route_'+str(16)+'"/>')
                    vehicleid=vehicleid+1  
                elif int(df['Direction'][i].split(" ",1)[1]) == 3:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(10*60))+'.00" route="route_'+str(17)+'"/>')
                    vehicleid=vehicleid+1
                elif int(df['Direction'][i].split(" ",1)[1]) == 5:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(10*60))+'.00" route="route_'+str(18)+'"/>')
                    vehicleid=vehicleid+1
                elif int(df['Direction'][i].split(" ",1)[1]) == 6:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(10*60))+'.00" route="route_'+str(14)+'"/>')
                    vehicleid=vehicleid+1
                elif int(df['Direction'][i].split(" ",1)[1]) == 13:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(10*60))+'.00" route="route_'+str(15)+'"/>')
                    vehicleid=vehicleid+1
                elif int(df['Direction'][i].split(" ",1)[1]) == 14:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(10*60))+'.00" route="route_'+str(19)+'"/>')
                    vehicleid=vehicleid+1  
                else:
                    print('Something Wrong')
                    
            elif int(df['Time'][i][3:5]) <62:
                if int(df['Direction'][i].split(" ",1)[1]) == 1:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(15*60))+'.00" route="route_'+str(16)+'"/>')
                    vehicleid=vehicleid+1  
                elif int(df['Direction'][i].split(" ",1)[1]) == 3:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(15*60))+'.00" route="route_'+str(17)+'"/>')
                    vehicleid=vehicleid+1
                elif int(df['Direction'][i].split(" ",1)[1]) == 5:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(15*60))+'.00" route="route_'+str(18)+'"/>')
                    vehicleid=vehicleid+1
                elif int(df['Direction'][i].split(" ",1)[1]) == 6:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(15*60))+'.00" route="route_'+str(14)+'"/>')
                    vehicleid=vehicleid+1
                elif int(df['Direction'][i].split(" ",1)[1]) == 13:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(15*60))+'.00" route="route_'+str(15)+'"/>')
                    vehicleid=vehicleid+1    
                elif int(df['Direction'][i].split(" ",1)[1]) == 14:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="bus" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(15*60))+'.00" route="route_'+str(19)+'"/>')
                    vehicleid=vehicleid+1  
                else:
                    print('Something Wrong')   
                    
                 
            else:
                print('Something Wrong')
        
    elif df['Type'][i]==' Tram' or df['Type'][i]=='Tram' or df['Type'][i]=='Tram ' or df['Type'][i]==' Tram ':
        
        for n in range (0, int(df['Number'][i])):
            
            if int(df['Time'][i][3:5]) <12:
                
                if int(df['Direction'][i].split(" ",1)[1]) == 1:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="tram" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8]))+'.00" route="route_'+str(21)+'"/>')
                    vehicleid=vehicleid+1  
                elif int(df['Direction'][i].split(" ",1)[1]) == 14:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="tram" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8]))+'.00" route="route_'+str(20)+'"/>')
                    vehicleid=vehicleid+1  
                else:
                    print('Something Wrong')
                    
            elif int(df['Time'][i][3:5]) <27:
                if int(df['Direction'][i].split(" ",1)[1]) == 1:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="tram" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(5*60))+'.00" route="route_'+str(21)+'"/>')
                    vehicleid=vehicleid+1  
                elif int(df['Direction'][i].split(" ",1)[1]) == 14:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="tram" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(5*60))+'.00" route="route_'+str(20)+'"/>')
                    vehicleid=vehicleid+1  
                else:
                    print('Something Wrong')
                    
            elif int(df['Time'][i][3:5]) <42:
                if int(df['Direction'][i].split(" ",1)[1]) == 1:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="tram" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(10*60))+'.00" route="route_'+str(21)+'"/>')
                    vehicleid=vehicleid+1  
                elif int(df['Direction'][i].split(" ",1)[1]) == 14:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="tram" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(10*60))+'.00" route="route_'+str(20)+'"/>')
                    vehicleid=vehicleid+1  
                else:
                    print('Something Wrong')
                    
            elif int(df['Time'][i][3:5]) <62:
                if int(df['Direction'][i].split(" ",1)[1]) == 1:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="tram" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(15*60))+'.00" route="route_'+str(21)+'"/>')
                    vehicleid=vehicleid+1  
                elif int(df['Direction'][i].split(" ",1)[1]) == 14:
                    xml.append('<vehicle id="vehicle_'+str(vehicleid)+'" type="tram" depart="'+str(int(df['Time'][i][3:5])*60+int(df['Time'][i][6:8])-(15*60))+'.00" route="route_'+str(20)+'"/>')
                    vehicleid=vehicleid+1  
                else:
                    print('Something Wrong')   
                    
                 
            else:
                print('Something Wrong')
    elif df['Type'][i]==' Bike' or df['Type'][i]=='Bike' or df['Type'][i]=='Bike ' or df['Type'][i]==' Bike ':
        pass
    else:
        print('Something Wrong')

# %%
#save the file in a text format and later can be saved in the rou.xml file of the SUMO simulation. This contains all the vehicles in the dataset. 
with open("filename.txt", "w") as txt_file:
    for line in xml:
        txt_file.write("".join(line) + "\n")
